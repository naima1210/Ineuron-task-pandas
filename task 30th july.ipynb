# %%
import pandas as pd

# %%
1 .Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave
2 .Total working days for each agents 
3. Total query that you hvae taken 
4. #total Feedback that you have received 
5. a agent name who have average rating between 3.5 to 4 
6 . Agent name who have rating lesss then 3.5 
7 . agent name who have rating more then 4.5 
8 . how many feedaback agents have received more then 4.5 average
9 . average weekly response time for each agent 
10 . average weekely resolution time for each agents 
11 . list of all agents name 
12 . percentage of chat on which they have received a feedback 
13 . Total contributation hour for each and every agents weekly basis 
14. total percentage of active hour for a month 

sunny.savita@ineuron.ai ,sudhanshu@ineuron.ai

deadline of complition of this task is 12 AM IST today 

After that if you will submit your task i wont evaluate it at all , excuses will be given to new 
joiners

# %%
agent_login=pd.read_csv(r"C:\Users\HP\Downloads\Agentloginreport.csv")

# %%
agent_login=pd.read_csv(r"C:\Users\HP\Downloads\Agentloginreport.csv",header=1)

# %%
agent_login=pd.read_csv(r"C:\Users\HP\Downloads\Agentloginreport.csv",header=2)

# %%
agent_login=pd.read_csv(r"C:\Users\HP\Downloads\Agentloginreport.csv",parse_dates = ['Date'],header=2)

# %%
agent_login.head()
# Out:
#    SL No               Agent       Date   Login Time  Logout Time  Duration
# 0      1  Shivananda Sonwane 2022-07-30  03:35:29 PM  05:39:39 PM  02:04:10
# 1      2      Khushboo Priya 2022-07-30  03:06:59 PM  03:07:16 PM  00:00:17
# 2      3       Nandani Gupta 2022-07-30  03:04:24 PM  05:31:07 PM  02:26:42
# 3      4     Hrisikesh Neogi 2022-07-30  02:34:29 PM  03:19:35 PM  00:45:06
# 4      5             Mukesh  2022-07-30  02:03:15 PM  03:11:52 PM  01:08:36

# %%
agent_login.shape
# Out:
# (1000, 6)

# %%
agent_login['Day'] = agent_login['Date'].dt.day

# %%
agent_login['Month'] = agent_login['Date'].dt.month

# %%
agent_login['Year'] = agent_login['Date'].dt.year

# %%
agent_login['Week'] = agent_login['Date'].dt.isocalendar().week

# %%
agent_login['Duration'] = pd.to_timedelta(agent_login['Duration'])

# %%
agent_login['Login time'] = pd.to_timedelta(agent_login['Login Time'])

# %%
agent_login['Logout time'] = pd.to_timedelta(agent_login['Logout Time'])

# %%
agent_login.head()
# Out:
#    SL No               Agent       Date   Login Time  Logout Time  \
# 0      1  Shivananda Sonwane 2022-07-30  03:35:29 PM  05:39:39 PM
# 1      2      Khushboo Priya 2022-07-30  03:06:59 PM  03:07:16 PM
# 2      3       Nandani Gupta 2022-07-30  03:04:24 PM  05:31:07 PM
# 3      4     Hrisikesh Neogi 2022-07-30  02:34:29 PM  03:19:35 PM
# 4      5             Mukesh  2022-07-30  02:03:15 PM  03:11:52 PM
#
#          Duration  Day  Month  Year  Week      Login time     Logout time
# 0 0 days 02:04:10   30      7  2022    30 0 days 03:35:29 0 days 05:39:39
# 1 0 days 00:00:17   30      7  2022    30 0 days 03:06:59 0 days 03:07:16
# 2 0 days 02:26:42   30      7  2022    30 0 days 03:04:24 0 days 05:31:07
# 3 0 days 00:45:06   30      7  2022    30 0 days 02:34:29 0 days 03:19:35
# 4 0 days 01:08:36   30      7  2022    30 0 days 02:03:15 0 days 03:11:52

# %%
agent_performance=pd.read_csv(r"C:\Users\HP\Downloads\Agentperformance.csv",parse_dates = ['Date'],header=1)

# %%
agent_performance.head()
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1 2022-07-30   Prerna Singh           11              00:00:38
# 1      2 2022-07-30  Nandani Gupta           11              00:01:15
# 2      3 2022-07-30     Ameya Jain           14              00:00:30
# 3      4 2022-07-30  Mahesh Sarade           14              00:01:04
# 4      5 2022-07-30         Swati            14              00:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback
# 0                00:04:20            4.11               9
# 1                00:28:25            3.14               7
# 2                00:11:36            4.55              11
# 3                00:15:46            4.71               7
# 4                00:16:33            3.67               6

# %%
agent_performance['Day']=agent_performance['Date'].dt.day

# %%
agent_performance['Month']=agent_performance['Date'].dt.month

# %%
agent_performance['Year']=agent_performance['Date'].dt.year

# %%
agent_performance['Week']=agent_performance['Date'].dt.week
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_10452/139965293.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   agent_performance['Week']=agent_performance['Date'].dt.week

# %%
agent_performance['Average Response Time'] = pd.to_timedelta(agent_performance['Average Response Time'])

# %%
agent_performance['Average Resolution Time'] = pd.to_timedelta(agent_performance['Average Resolution Time'])

# %%
agent_performance.head()
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1 2022-07-30   Prerna Singh           11       0 days 00:00:38
# 1      2 2022-07-30  Nandani Gupta           11       0 days 00:01:15
# 2      3 2022-07-30     Ameya Jain           14       0 days 00:00:30
# 3      4 2022-07-30  Mahesh Sarade           14       0 days 00:01:04
# 4      5 2022-07-30         Swati            14       0 days 00:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback  Day  Month  Year  \
# 0         0 days 00:04:20            4.11               9   30      7  2022
# 1         0 days 00:28:25            3.14               7   30      7  2022
# 2         0 days 00:11:36            4.55              11   30      7  2022
# 3         0 days 00:15:46            4.71               7   30      7  2022
# 4         0 days 00:16:33            3.67               6   30      7  2022
#
#    Week
# 0    30
# 1    30
# 2    30
# 3    30
# 4    30

# %%
agent_login.head()
# Out:
#    SL No               Agent       Date   Login Time  Logout Time  \
# 0      1  Shivananda Sonwane 2022-07-30  03:35:29 PM  05:39:39 PM
# 1      2      Khushboo Priya 2022-07-30  03:06:59 PM  03:07:16 PM
# 2      3       Nandani Gupta 2022-07-30  03:04:24 PM  05:31:07 PM
# 3      4     Hrisikesh Neogi 2022-07-30  02:34:29 PM  03:19:35 PM
# 4      5             Mukesh  2022-07-30  02:03:15 PM  03:11:52 PM
#
#          Duration  Day  Month  Year  Week      Login time     Logout time
# 0 0 days 02:04:10   30      7  2022    30 0 days 03:35:29 0 days 05:39:39
# 1 0 days 00:00:17   30      7  2022    30 0 days 03:06:59 0 days 03:07:16
# 2 0 days 02:26:42   30      7  2022    30 0 days 03:04:24 0 days 05:31:07
# 3 0 days 00:45:06   30      7  2022    30 0 days 02:34:29 0 days 03:19:35
# 4 0 days 01:08:36   30      7  2022    30 0 days 02:03:15 0 days 03:11:52

# %%
#1 .Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave

# %%
agent_performance.groupby(['Agent Name', 'Week'])['Average Rating'].mean()
# Out:
# Agent Name  Week
# Abhishek    26      0.000000
#             27      0.000000
#             28      0.000000
#             29      0.000000
#             30      0.000000
#                       ...
# Zeeshan     26      0.000000
#             27      1.307143
#             28      2.948571
#             29      3.180000
#             30      2.760000
# Name: Average Rating, Length: 350, dtype: float64

# %%
#2 .Total working days for each agents

# %%
agent_login.groupby(['Agent'])['Day'].nunique()
# Out:
# Agent
# Aditya Shinde              1
# Aditya_iot                 8
# Amersh                     2
# Ameya Jain                 7
# Ankitjha                   2
# Anurag Tiwari             10
# Aravind                    7
# Ayushi Mishra              9
# Bharath                    8
# Boktiar Ahmed Bappy        9
# Chaitra K Hiremath         7
# Deepranjan Gupta          10
# Dibyanshu                  9
# Harikrishnan Shaji         9
# Hrisikesh Neogi            9
# Hyder Abbas                2
# Ineuron Intelligence       1
# Ishawant Kumar            11
# Jawala Prakash             9
# Jaydeep Dixit              7
# Khushboo Priya             8
# Madhulika G                8
# Mahesh Sarade              8
# Maitry                     5
# Manjunatha A               7
# Mithun S                   8
# Mukesh                     2
# Muskan Garg                6
# Nandani Gupta              9
# Nishtha Jain               8
# Nitin M                    1
# Prabir Kumar Satapathy     7
# Prateek _iot              11
# Prerna Singh               9
# Rishav Dash                7
# Saikumarreddy N            7
# Sanjeev Kumar              9
# Saurabh Shukla             4
# Shiva Srivastava           8
# Shivan K                   8
# Shivananda Sonwane        10
# Shubham Sharma            11
# Sowmiya Sivakumar          8
# Sudhanshu Kumar            6
# Suraj S Bilgi              2
# Swati                      4
# Tarun                      1
# Wasim                      9
# Zeeshan                    9
# Name: Day, dtype: int64

# %%
#3. Total query that you hvae taken

# %%
agent_performance.groupby(['Agent Name'])['Total Chats'].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    277
# Aditya_iot       231
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             44
# Wasim            433
# Zeeshan          542
# Name: Total Chats, Length: 70, dtype: int64

# %%
#4.Total Feedback that you have received.

# %%
agent_performance.groupby(['Agent Name'])['Total Feedback'].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    153
# Aditya_iot       131
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             20
# Wasim            284
# Zeeshan          335
# Name: Total Feedback, Length: 70, dtype: int64

# %%
#5. a agent name who have average rating between 3.5 to 4

# %%
rating=agent_performance.groupby('Agent Name')['Average Rating'].mean()

# %%
rating = pd.DataFrame(rating)

# %%
rating
# Out:
#                Average Rating
# Agent Name
# Abhishek             0.000000
# Aditya               0.000000
# Aditya Shinde        1.800333
# Aditya_iot           2.345333
# Amersh               0.000000
# ...                       ...
# Uday Mishra          0.000000
# Vasanth P            0.000000
# Vivek                0.500667
# Wasim                2.400000
# Zeeshan              2.287000
#
# [70 rows x 1 columns]

# %%
rating[(rating['Average Rating'] > 3.5) &(rating['Average Rating'] < 4)]
# Out:
#                      Average Rating
# Agent Name
# Boktiar Ahmed Bappy        3.568000
# Ishawant Kumar             3.543333
# Khushboo Priya             3.703667
# Manjunatha A               3.594667

# %%
#6 Agent name who have rating lesss then 3.5

# %%
rating[rating['Average Rating'] < 3.5]
# Out:
#                Average Rating
# Agent Name
# Abhishek             0.000000
# Aditya               0.000000
# Aditya Shinde        1.800333
# Aditya_iot           2.345333
# Amersh               0.000000
# ...                       ...
# Uday Mishra          0.000000
# Vasanth P            0.000000
# Vivek                0.500667
# Wasim                2.400000
# Zeeshan              2.287000
#
# [65 rows x 1 columns]

# %%
#7 Agent name who have rating more then 4.5

# %%
rating[rating['Average Rating'] > 4.5]
# Out:
# Empty DataFrame
# Columns: [Average Rating]
# Index: []

# %%
#8 . In How many feedabacks agents have received more then 4.5 average.

# %%
df = agent_performance[['Agent Name' , 'Total Feedback' , 'Average Rating']]
df
# Out:
#               Agent Name  Total Feedback  Average Rating
# 0           Prerna Singh               9            4.11
# 1          Nandani Gupta               7            3.14
# 2             Ameya Jain              11            4.55
# 3          Mahesh Sarade               7            4.71
# 4                 Swati                6            3.67
# ...                  ...             ...             ...
# 2155   Sowmiya Sivakumar               0            0.00
# 2156             Nitin M               0            0.00
# 2157              Vivek                0            0.00
# 2158       Ayushi Mishra               0            0.00
# 2159  Chaitra K Hiremath               0            0.00
#
# [2160 rows x 3 columns]

# %%
df[df['Average Rating'] > 4.5]
# Out:
#               Agent Name  Total Feedback  Average Rating
# 2             Ameya Jain              11            4.55
# 3          Mahesh Sarade               7            4.71
# 5                Mukesh                8            4.62
# 6        Saikumarreddy N              12            5.00
# 7          Sanjeev Kumar               6            5.00
# ...                  ...             ...             ...
# 2100      Shubham Sharma              13            5.00
# 2101       Jaydeep Dixit              13            4.77
# 2102  Shivananda Sonwane              14            4.86
# 2103      Khushboo Priya              18            4.61
# 2104     Hrisikesh Neogi               9            4.56
#
# [307 rows x 3 columns]

# %%
df['Total Feedback'].sum()
# Out:
# 9259

# %%
#9 Average weekly response time for each agent.

# %%
agent_performance.groupby(['Agent Name', 'Week'])['Average Response Time'].mean()
# Out:
# Agent Name  Week
# Abhishek    26               0 days 00:00:00
#             27               0 days 00:00:00
#             28               0 days 00:00:00
#             29               0 days 00:00:00
#             30               0 days 00:00:00
#                               ...
# Zeeshan     26               0 days 00:00:00
#             27     0 days 00:00:23.571428571
#             28     0 days 00:02:03.428571428
#             29     0 days 00:01:02.857142857
#             30     0 days 00:01:03.833333333
# Name: Average Response Time, Length: 350, dtype: timedelta64[ns]

# %%
#10List of all agents name.

# %%
agent_performance['Agent Name'].unique()
# Out:
# array(['Prerna Singh', 'Nandani Gupta', 'Ameya Jain', 'Mahesh Sarade',
#        'Swati ', 'Mukesh ', 'Saikumarreddy N', 'Sanjeev Kumar',
#        'Shubham Sharma', 'Nishtha Jain', 'Manjunatha A', 'Khushboo Priya',
#        'Suraj S Bilgi', 'Harikrishnan Shaji', 'Hrisikesh Neogi',
#        'Shivan K', 'Sowmiya Sivakumar', 'Madhulika G', 'Mithun S',
#        'Hitesh Choudhary', 'Sanjeevan ', 'Anirudh ', 'Shiva Srivastava',
#        'Dibyanshu ', 'Ashish ', 'Uday Mishra', 'Aditya Shinde',
#        'Jayant Kumar', 'Aditya_iot ', 'Prabir Kumar Satapathy',
#        'Saurabh Shukla', 'Wasim ', 'Samprit ', 'Maitry ', 'Abhishek ',
#        'Rishav Dash', 'Aravind ', 'Tarun ', 'Muskan Garg', 'Ankit Sharma',
#        'Bharath ', 'Ashad Nasim', 'Vasanth P', 'Aditya ', 'Amersh ',
#        'Sandipan Saha', 'Ineuron Intelligence ', 'Mahak ', 'Mukesh Rao ',
#        'Zeeshan ', 'Anurag Tiwari', 'Ankitjha ', 'Saif Khan',
#        'Jaydeep Dixit', 'Sudhanshu Kumar', 'Maneesh ', 'Hyder Abbas',
#        'Rohan ', 'Vivek ', 'Nitin M', 'Shivan_S ', 'Spuri ',
#        'Ayushi Mishra', 'Chaitra K Hiremath', 'Prateek _iot ',
#        'Boktiar Ahmed Bappy', 'Shivananda Sonwane', 'Ishawant Kumar',
#        'Deepranjan Gupta', 'Jawala Prakash'], dtype=object)

# %%
#11Percentage of chat on which they have received a feedback.

# %%
agent_performance['Percentage'] =(agent_performance['Total Feedback'] / agent_performance['Total Chats']) * 100

# %%
agent_performance
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1 2022-07-30        Prerna Singh           11       0 days 00:00:38
# 1         2 2022-07-30       Nandani Gupta           11       0 days 00:01:15
# 2         3 2022-07-30          Ameya Jain           14       0 days 00:00:30
# 3         4 2022-07-30       Mahesh Sarade           14       0 days 00:01:04
# 4         5 2022-07-30              Swati            14       0 days 00:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156 2022-07-01   Sowmiya Sivakumar            0       0 days 00:00:00
# 2156   2157 2022-07-01             Nitin M            0       0 days 00:00:00
# 2157   2158 2022-07-01              Vivek             0       0 days 00:00:00
# 2158   2159 2022-07-01       Ayushi Mishra            0       0 days 00:00:00
# 2159   2160 2022-07-01  Chaitra K Hiremath            0       0 days 00:00:00
#
#      Average Resolution Time  Average Rating  Total Feedback